# %%
import torch
import torch.nn as nn
import numpy as np
import joblib
import os
import sys
import matplotlib.pyplot as plt

# %%
common_dir_name = 'commons' 
common_dir_path = os.path.join(os.path.dirname(os.getcwd()), common_dir_name)
if common_dir_path not in sys.path:
    sys.path.append(common_dir_path)

# %%
from utils_chkpt import load_checkpoint
from nn_model_plausible import PlausibleHNN
from utils_orbit import scipy_predict_qp_model_orbits
from utils_orbit import ground_truth_orbits
from utils_energy import calculate_gt_hamiltonian
from utils_energy import calculate_nn_hamiltonian
from utils_plot import get_global_limits
from utils_plot import eval_on_test_set

# %%
torch.set_default_dtype(torch.float64)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device='cpu'

# %%
import gc
gc.collect()
# Out:
# 0

# %%
EPOC  = 7
EPOCS = 20

LAYERS = 4
FAC = 10

MODEL_NAME=f"p-hnn({LAYERS})({FAC})"
MODEL_DIR="./checkpoints/multi-scale-v2"

BATCH_SZ = 1024
LR_INIT = 1e-4
MIN_LR = 1e-6
PATIENCE = 3

PLOT_ROOT_DIR="./figures"

EVAL_PLOT_DIR=f"{PLOT_ROOT_DIR}/eval"
EVAL_FIG_DIR=f"{EVAL_PLOT_DIR}/multi-scale-v2"
if not os.path.exists(EVAL_FIG_DIR):
    os.makedirs(EVAL_FIG_DIR, exist_ok=True)

FIT_PLOT_DIR=f"{PLOT_ROOT_DIR}/fit"
FIT_FIG_DIR=f"{FIT_PLOT_DIR}/multi-scale-v2"
if not os.path.exists(FIT_FIG_DIR):
    os.makedirs(FIT_FIG_DIR, exist_ok=True)

PREFIX="scipy_"
POSTFIX=f"_bs_{BATCH_SZ}_lr_{LR_INIT:.0e}_pat_{PATIENCE}"

# %%
extend_time_window_upto_200Y = False
extend_time_window_upto_100Y = False

if extend_time_window_upto_200Y:
    extend_time_window_upto_100Y = True

IMG_SAVE = False # True

# %%
stats = joblib.load(f'{MODEL_DIR}/ds_mlt_scalev.pkl')
q_max = stats['q_max']
p_max = stats['p_max']
dq_max = stats['dq_max']
dp_max = stats['dp_max']
print('Loaded q_max:', q_max)
print('Loaded p_max:', p_max)
print('Loaded dq_max:', dq_max)
print('Loaded dp_max:', dp_max)
# Out:
# Loaded q_max: [9.76072648e-03 9.76072648e-03 9.76072648e-03 4.75583884e-01
#  4.75583884e-01 4.75583884e-01 7.36863945e-01 7.36863945e-01
#  7.36863945e-01 1.02686268e+00 1.02686268e+00 1.02686268e+00
#  1.67630733e+00 1.67630733e+00 1.67630733e+00 5.46068795e+00
#  5.46068795e+00 5.46068795e+00 1.00744475e+01 1.00744475e+01
#  1.00744475e+01 2.01200978e+01 2.01200978e+01 2.01200978e+01
#  3.03526597e+01 3.03526597e+01 3.03526597e+01 4.93888156e+01
#  4.93888156e+01 4.93888156e+01]
# Loaded p_max: [3.46495531e-03 3.46495531e-03 3.46495531e-03 2.06714022e-06
#  2.06714022e-06 2.06714022e-06 1.82197738e-05 1.82197738e-05
#  1.82197738e-05 1.92061355e-05 1.92061355e-05 1.92061355e-05
#  1.80700775e-06 1.80700775e-06 1.80700775e-06 2.76473141e-03
#  2.76473141e-03 2.76473141e-03 6.14944300e-04 6.14944300e-04
#  6.14944300e-04 6.57900454e-05 6.57900454e-05 6.57900454e-05
#  5.96100788e-05 5.96100788e-05 5.96100788e-05 8.45747270e-09
#  8.45747270e-09 8.45747270e-09]
# Loaded dq_max: [3.46495531e-03 3.46495531e-03 3.46495531e-03 1.24479779e+01
#  1.24479779e+01 1.24479779e+01 7.44138452e+00 7.44138452e+00
#  7.44138452e+00 6.39458420e+00 6.39458420e+00 6.39458420e+00
#  5.59921505e+00 5.59921505e+00 5.59921505e+00 2.89613768e+00
#  2.89613768e+00 2.89613768e+00 2.15146109e+00 2.15146109e+00
#  2.15146109e+00 1.50688934e+00 1.50688934e+00 1.50688934e+00
#  1.15741074e+00 1.15741074e+00 1.15741074e+00 1.29063110e+00
#  1.29063110e+00 1.29063110e+00]
# Loaded dp_max: [2.01141647e-03 2.01141647e-03 2.01141647e-03 6.93873693e-05
#  6.93873693e-05 6.93873693e-05 1.87311448e-04 1.87311448e-04
#  1.87311448e-04 1.22641230e-04 1.22641230e-04 1.22641230e-04
#  6.69435451e-06 6.69435451e-06 6.69435451e-06 1.54379089e-03
#  1.54379089e-03 1.54379089e-03 1.39365872e-04 1.39365872e-04
#  1.39365872e-04 5.17883200e-06 5.17883200e-06 5.17883200e-06
#  2.29487922e-06 2.29487922e-06 2.29487922e-06 2.94688623e-10
#  2.94688623e-10 2.94688623e-10]

# %%
weight_filename = f"{MODEL_NAME}_ep_{EPOC}_of_{EPOCS}{POSTFIX}"
weight_filepath = f"{MODEL_DIR}/" + weight_filename + '.pth'

print('weight_file_path":', weight_filepath)

model = PlausibleHNN(fac=FAC, num_layers=LAYERS)
model.double()
model.to(device)

load_checkpoint(model, optimizer=None, file_path=weight_filepath)
# Out:
# weight_file_path": ./checkpoints/multi-scale-v2/p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.pth
# 🚀 Loaded checkpoint from './checkpoints/multi-scale-v2/p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.pth' (Epoch 7)
# (7, 0.0006252737336996837)

# %%
print(model)
print(f"Number of parameters: {sum(p.numel() for p in model.parameters())}")
# Out:
# PlausibleHNN(
#   (v_mlp): MLP(
#     (net): Sequential(
#       (0): Linear(in_features=30, out_features=1350, bias=True)
#       (1): EvenActivation()
#       (2): Linear(in_features=1350, out_features=1350, bias=True)
#       (3): EvenActivation()
#       (4): Linear(in_features=1350, out_features=1350, bias=True)
#       (5): EvenActivation()
#       (6): Linear(in_features=1350, out_features=1, bias=False)
#     )
#   )
# )
# Number of parameters: 3690930

# %%
print(f'T-net attention weights: {model.w}')
# Out:
# T-net attention weights: Parameter containing:
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5019, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000], device='cuda:0', requires_grad=True)

# %%
target_path = os.path.join(os.path.dirname(os.getcwd()), 'data_ode')

if target_path not in sys.path:
    sys.path.append(target_path)
pos_path = f"{target_path}/q.npz"
mom_path = f"{target_path}/p.npz"
dpos_path = f"{target_path}/dq.npz"
dmom_path = f"{target_path}/dp.npz"

plt_pars = get_global_limits(pos_path)

# %%
q_path = f"{target_path}/q.npz"
p_path = f"{target_path}/p.npz"

# %%
start_idx = 1_600_000 # 2_000_000 * 0.8
dt = 0.0005 # 1 year = 2_000 steps, so 0.0005 corresponds to 1 step = 0.0005 year, and 1000 steps = 0.5 year,

# upto 50 Years
eval_steps = [1_000, 2_000, 4_000, 6_000, 8_000, 10_000, 20_000, 30_000, 40_000, 100_000]

if extend_time_window_upto_100Y:
   eval_steps += [200_000]
if extend_time_window_upto_200Y:
   eval_steps += [300_000, 400_000]


gt_q, gt_p = ground_truth_orbits(q_path, p_path, start_idx, eval_steps[-1])

if len(eval_steps) > 0:
    FIG_PREFIX = PREFIX
       
    eval_on_test_set(model, device, 
                 q_max, p_max, dq_max, dp_max, dt,
                 eval_steps, gt_q, gt_p, start_idx, 
                 FIG_PREFIX, weight_filename, EVAL_FIG_DIR,
                 plt_scale_pars=plt_pars, 
                 qp_cat=False, 
                 img_save=IMG_SAVE)
# Out:
# i: 0, interval=[0 : 1000]
# x0: (1, 60)
# /home/danieljh/py-venv/lib/python3.12/site-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# scipy_eval_[0 : 1000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# scipy_metric_[0 : 1000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# i: 1, interval=[0 : 2000]
# x0: (1, 60)
# scipy_eval_[0 : 2000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# scipy_metric_[0 : 2000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# i: 2, interval=[0 : 4000]
# x0: (1, 60)
# scipy_eval_[0 : 4000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# scipy_metric_[0 : 4000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# i: 3, interval=[0 : 6000]
# x0: (1, 60)
# scipy_eval_[0 : 6000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# scipy_metric_[0 : 6000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# i: 4, interval=[0 : 8000]
# x0: (1, 60)
# scipy_eval_[0 : 8000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# scipy_metric_[0 : 8000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# i: 5, interval=[0 : 10000]
# x0: (1, 60)
# scipy_eval_[0 : 10000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# scipy_metric_[0 : 10000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# i: 6, interval=[0 : 20000]
# x0: (1, 60)
# scipy_eval_[0 : 20000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# scipy_metric_[0 : 20000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# i: 7, interval=[0 : 30000]
# x0: (1, 60)
# scipy_eval_[0 : 30000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# scipy_metric_[0 : 30000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# i: 8, interval=[0 : 40000]
# x0: (1, 60)
# scipy_eval_[0 : 40000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# scipy_metric_[0 : 40000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# i: 9, interval=[0 : 100000]
# x0: (1, 60)
# scipy_eval_[0 : 100000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
# scipy_metric_[0 : 100000]_p-hnn(4)(10)_ep_7_of_20_bs_1024_lr_1e-04_pat_3.webp
