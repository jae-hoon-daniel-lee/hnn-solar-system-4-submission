# %%
import torch
import torch.nn as nn
import numpy as np
import joblib
import os
import sys
import matplotlib.pyplot as plt

# %%
common_dir_name = 'commons' 
common_dir_path = os.path.join(os.path.dirname(os.getcwd()), common_dir_name)
if common_dir_path not in sys.path:
    sys.path.append(common_dir_path)

# %%
from utils_chkpt import load_checkpoint
from nn_model_baseline import HNN
from utils_orbit import scipy_predict_qp_model_orbits
from utils_orbit import ground_truth_orbits
from utils_energy import calculate_gt_hamiltonian
from utils_energy import calculate_nn_hamiltonian
from utils_plot import get_global_limits
from utils_plot import eval_on_test_set

# %%
torch.set_default_dtype(torch.float64)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device='cpu'

# %%
import gc
gc.collect()
# Out:
# 0

# %%
print(torch.cuda.mem_get_info()) # (free, total)
print('Current allocated GPU memory:', torch.cuda.memory_allocated())
# Out:
# (7407861760, 8082554880)
# Current allocated GPU memory: 0

# %%
EPOC  = 19934
EPOCS = 20000
LAYERS = 3
HIDDEN_DIMS = 240

BATCH_SZ = 8192

MODEL_NAME = f"unisc-baseline-hnn({LAYERS})({HIDDEN_DIMS})"
MODEL_DIR = "./checkpoints/uni-scale"

LR_INIT  = 1e-2
MIN_LR   = 1e-6
PATIENCE = 3

PREFIX=""
POSTFIX=f"_bs_{BATCH_SZ}_lr_{LR_INIT:.0e}_pat_{PATIENCE}"

PLOT_ROOT_DIR="./figures"

EVAL_PLOT_DIR=f"{PLOT_ROOT_DIR}/eval"
EVAL_FIG_DIR=f"{EVAL_PLOT_DIR}/uni-scale"
if not os.path.exists(EVAL_FIG_DIR):
    os.makedirs(EVAL_FIG_DIR, exist_ok=True)

FIT_PLOT_DIR=f"{PLOT_ROOT_DIR}/fit"
FIT_FIG_DIR=f"{FIT_PLOT_DIR}/uni-scale"
if not os.path.exists(FIT_FIG_DIR):
    os.makedirs(FIT_FIG_DIR, exist_ok=True)

PREFIX="scipy_"
POSTFIX=f"_bs_{BATCH_SZ}_lr_{LR_INIT:.0e}_pat_{PATIENCE}"

# %%
extend_time_window_upto_100Y = True

IMG_SAVE = False

# %%
stats = joblib.load(f'{MODEL_DIR}/ds_uni_scalev.pkl')
q_max = stats['q_max']
p_max = stats['p_max']
dq_max = stats['dq_max']
dp_max = stats['dp_max']
print('Loaded q_max:', q_max)
print('Loaded p_max:', p_max)
print('Loaded dq_max:', dq_max)
print('Loaded dp_max:', dp_max)
# Out:
# Loaded q_max: 45.38344355063725
# Loaded p_max: 0.003417047471518064
# Loaded dq_max: 12.357885035685767
# Loaded dp_max: 0.0020103043130452304

# %%
print(torch.cuda.mem_get_info()) # (free, total)
print('Current allocated GPU memory:', torch.cuda.memory_allocated())
print('Maximum allocated GPU memory:', torch.cuda.max_memory_allocated())
# Out:
# (7407861760, 8082554880)
# Current allocated GPU memory: 0
# Maximum allocated GPU memory: 0

# %%
weight_filename = f"{MODEL_NAME}_ep_{EPOC}_of_{EPOCS}{POSTFIX}"
weight_filepath = f"{MODEL_DIR}/" + weight_filename + '.pth'

print('weight_file_path":', weight_filepath)

model = HNN(input_dim=10*3*2, hidden_dim=HIDDEN_DIMS, num_layers=LAYERS, actv=nn.Tanh)
model.double()
model.to(device)

load_checkpoint(model, optimizer=None, file_path=weight_filepath)
# Out:
# weight_file_path": ./checkpoints/uni-scale/unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.pth
# 🚀 Loaded checkpoint from './checkpoints/uni-scale/unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.pth' (Epoch 19934)
# (19934, 9.800262839738756e-07)

# %%
print(model)
print(f"Number of parameters: {sum(p.numel() for p in model.parameters())}")
# Out:
# HNN(
#   (net): MLP(
#     (net): Sequential(
#       (0): Linear(in_features=60, out_features=240, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=240, out_features=240, bias=True)
#       (3): Tanh()
#       (4): Linear(in_features=240, out_features=1, bias=True)
#     )
#   )
# )
# Number of parameters: 72721

# %%
target_path = os.path.join(os.path.dirname(os.getcwd()), 'data_ode')

if target_path not in sys.path:
    sys.path.append(target_path)
pos_path = f"{target_path}/q.npz"
mom_path = f"{target_path}/p.npz"
dpos_path = f"{target_path}/dq.npz"
dmom_path = f"{target_path}/dp.npz"

plt_pars = get_global_limits(pos_path)

# %%
q_path = f"{target_path}/q.npz"
p_path = f"{target_path}/p.npz"

# %%
start_idx = 1_600_000 # 2_000_000 * 0.8
dt = 0.0005 # 1 year = 2_000 steps, so 0.0005 corresponds to 1 step = 0.0005 year, and 1000 steps = 0.5 year,

# upto 50 Years
eval_steps = [1_000, 2_000, 4_000, 6_000, 8_000, 10_000, 20_000, 30_000, 40_000, 100_000]

if extend_time_window_upto_100Y:
   eval_steps += [200_000]


gt_q, gt_p = ground_truth_orbits(q_path, p_path, start_idx, eval_steps[-1])

if len(eval_steps) > 0:
    FIG_PREFIX = PREFIX
       
    eval_on_test_set(model, device, 
                 q_max, p_max, dq_max, dp_max, dt,
                 eval_steps, gt_q, gt_p, start_idx, 
                 FIG_PREFIX, weight_filename, EVAL_FIG_DIR,
                 plt_scale_pars=plt_pars, 
                 qp_cat=True, 
                 img_save=IMG_SAVE)
# Out:
# i: 0, interval=[0 : 1000]
# x0: (1, 60)
# /home/danieljh/py-venv/lib/python3.12/site-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# scipy_eval_[0 : 1000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# scipy_metric_[0 : 1000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# i: 1, interval=[0 : 2000]
# x0: (1, 60)
# scipy_eval_[0 : 2000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# scipy_metric_[0 : 2000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# i: 2, interval=[0 : 4000]
# x0: (1, 60)
# scipy_eval_[0 : 4000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# scipy_metric_[0 : 4000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# i: 3, interval=[0 : 6000]
# x0: (1, 60)
# scipy_eval_[0 : 6000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# scipy_metric_[0 : 6000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# i: 4, interval=[0 : 8000]
# x0: (1, 60)
# scipy_eval_[0 : 8000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# scipy_metric_[0 : 8000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# i: 5, interval=[0 : 10000]
# x0: (1, 60)
# scipy_eval_[0 : 10000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# scipy_metric_[0 : 10000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# i: 6, interval=[0 : 20000]
# x0: (1, 60)
# scipy_eval_[0 : 20000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# scipy_metric_[0 : 20000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# i: 7, interval=[0 : 30000]
# x0: (1, 60)
# scipy_eval_[0 : 30000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# scipy_metric_[0 : 30000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# i: 8, interval=[0 : 40000]
# x0: (1, 60)
# scipy_eval_[0 : 40000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# scipy_metric_[0 : 40000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# i: 9, interval=[0 : 100000]
# x0: (1, 60)
# scipy_eval_[0 : 100000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# scipy_metric_[0 : 100000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# i: 10, interval=[0 : 200000]
# x0: (1, 60)
# scipy_eval_[0 : 200000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
# scipy_metric_[0 : 200000]_unisc-baseline-hnn(3)(240)_ep_19934_of_20000_bs_8192_lr_1e-02_pat_3.webp
