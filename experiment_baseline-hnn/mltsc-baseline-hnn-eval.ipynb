# %%
import torch
import torch.nn as nn
import numpy as np
import joblib
import os
import sys
import matplotlib.pyplot as plt

# %%
common_dir_name = 'commons' 
common_dir_path = os.path.join(os.path.dirname(os.getcwd()), common_dir_name)
if common_dir_path not in sys.path:
    sys.path.append(common_dir_path)

# %%
from utils_chkpt import load_checkpoint
from nn_model_baseline import HNN
from utils_orbit import scipy_predict_qp_model_orbits
from utils_orbit import ground_truth_orbits
from utils_energy import calculate_gt_hamiltonian
from utils_energy import calculate_nn_hamiltonian
from utils_plot import get_global_limits
from utils_plot import eval_on_test_set

# %%
torch.set_default_dtype(torch.float64)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device='cpu'

# %%
import gc
gc.collect()
# Out:
# 0

# %%
print(torch.cuda.mem_get_info()) # (free, total)
print('Current allocated GPU memory:', torch.cuda.memory_allocated())
# Out:
# (7972257792, 8082554880)
# Current allocated GPU memory: 0

# %%
EPOC  = 500
EPOCS = 500
LAYERS = 3
HIDDEN_DIMS = 240

BATCH_SZ = 8192

MODEL_NAME = f"mltsc-baseline-hnn({LAYERS})({HIDDEN_DIMS})"
MODEL_DIR = "./checkpoints/multi-scale"

LR_INIT  = 5e-3
MIN_LR   = 1e-6
PATIENCE = 2

PREFIX=""
POSTFIX=f"_bs_{BATCH_SZ}_lr_{LR_INIT:.0e}_pat_{PATIENCE}"

PLOT_ROOT_DIR="./figures"

EVAL_PLOT_DIR=f"{PLOT_ROOT_DIR}/eval"
EVAL_FIG_DIR=f"{EVAL_PLOT_DIR}/multi-scale"
if not os.path.exists(EVAL_FIG_DIR):
    os.makedirs(EVAL_FIG_DIR, exist_ok=True)

FIT_PLOT_DIR=f"{PLOT_ROOT_DIR}/fit"
FIT_FIG_DIR=f"{FIT_PLOT_DIR}/multi-scale"
if not os.path.exists(FIT_FIG_DIR):
    os.makedirs(FIT_FIG_DIR, exist_ok=True)

PREFIX="scipy_"
POSTFIX=f"_bs_{BATCH_SZ}_lr_{LR_INIT:.0e}_pat_{PATIENCE}"

IMG_SAVE=False # True

# %%
extend_time_window_upto_100Y = True

IMG_SAVE = False

# %%
stats = joblib.load(f'{MODEL_DIR}/ds_mlt_scalev.pkl')
q_max = stats['q_max']
p_max = stats['p_max']
dq_max = stats['dq_max']
dp_max = stats['dp_max']
print('Loaded q_max:', q_max)
print('Loaded p_max:', p_max)
print('Loaded dq_max:', dq_max)
print('Loaded dp_max:', dp_max)
# Out:
# Loaded q_max: [9.48517560e-03 9.64390518e-03 2.85918917e-04 4.03523820e-01
#  4.72064643e-01 5.14457213e-02 7.34011785e-01 7.35499984e-01
#  4.33065161e-02 1.01416617e+00 1.02625135e+00 2.48445588e-03
#  1.66629891e+00 1.58328122e+00 5.36736320e-02 5.44868654e+00
#  5.26998332e+00 1.24086481e-01 9.59921671e+00 1.00704028e+01
#  4.22218032e-01 2.01116438e+01 1.93075076e+01 2.70508762e-01
#  3.02546845e+01 3.02690767e+01 9.41224566e-01 4.40985562e+01
#  4.53834436e+01 1.42482687e+01]
# Loaded p_max: [3.32871162e-03 3.41704747e-03 8.82971507e-05 2.05217920e-06
#  1.78334285e-06 2.46468598e-07 1.81571684e-05 1.81773562e-05
#  1.07528402e-06 1.91971978e-05 1.89682074e-05 4.37021645e-08
#  1.71298239e-06 1.79760887e-06 5.46300954e-08 2.67060963e-03
#  2.75939269e-03 6.01212083e-05 6.14343908e-04 5.86895622e-04
#  2.67715731e-05 6.31952509e-05 6.57688110e-05 8.50272607e-07
#  5.94484322e-05 5.94169150e-05 1.83283159e-06 7.65083100e-09
#  7.95848484e-09 2.19627602e-09]
# Loaded dq_max: [3.32871162e-03 3.41704747e-03 8.82971507e-05 1.23578850e+01
#  1.07389968e+01 1.48419329e+00 7.41581496e+00 7.42406015e+00
#  4.39171305e-01 6.39160845e+00 6.31536726e+00 1.45504113e-02
#  5.30786697e+00 5.57009156e+00 1.69277443e-01 2.79754234e+00
#  2.89054521e+00 6.29787386e-02 2.14936054e+00 2.05332921e+00
#  9.36637641e-02 1.44745682e+00 1.50640298e+00 1.94750850e-02
#  1.15427215e+00 1.15366021e+00 3.55869178e-02 1.16753560e+00
#  1.21448433e+00 3.35157114e-01]
# Loaded dp_max: [2.01030431e-03 1.91632069e-03 5.54167723e-05 5.51832816e-05
#  6.88325451e-05 7.37325709e-06 1.86186752e-04 1.86647883e-04
#  1.10647819e-05 1.19670786e-04 1.22532757e-04 2.81254260e-07
#  6.63661143e-06 6.09137051e-06 2.14046540e-07 1.53797488e-03
#  1.44701670e-03 3.49745603e-05 1.27603101e-04 1.39310776e-04
#  5.67039911e-06 5.17623096e-06 4.80161064e-06 6.95642073e-08
#  2.28151179e-06 2.28300021e-06 7.11624186e-08 2.59585705e-10
#  2.66716050e-10 8.47769163e-11]

# %%
print(torch.cuda.mem_get_info()) # (free, total)
print('Current allocated GPU memory:', torch.cuda.memory_allocated())
print('Maximum allocated GPU memory:', torch.cuda.max_memory_allocated())
# Out:
# (7972257792, 8082554880)
# Current allocated GPU memory: 0
# Maximum allocated GPU memory: 0

# %%
weight_filename = f"{MODEL_NAME}_ep_{EPOC}_of_{EPOCS}{POSTFIX}"
weight_filepath = f"{MODEL_DIR}/" + weight_filename + '.pth'

print('weight_file_path":', weight_filepath)

model = HNN(input_dim=10*3*2, hidden_dim=HIDDEN_DIMS, num_layers=LAYERS, actv=nn.Tanh)
model.double()
model.to(device)

load_checkpoint(model, optimizer=None, file_path=weight_filepath)
# Out:
# weight_file_path": ./checkpoints/multi-scale/mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.pth
# 🚀 Loaded checkpoint from './checkpoints/multi-scale/mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.pth' (Epoch 500)
# (500, 0.0020044772256035638)

# %%
print(model)
print(f"Number of parameters: {sum(p.numel() for p in model.parameters())}")
# Out:
# HNN(
#   (net): MLP(
#     (net): Sequential(
#       (0): Linear(in_features=60, out_features=240, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=240, out_features=240, bias=True)
#       (3): Tanh()
#       (4): Linear(in_features=240, out_features=1, bias=True)
#     )
#   )
# )
# Number of parameters: 72721

# %%
target_path = os.path.join(os.path.dirname(os.getcwd()), 'data_ode')

if target_path not in sys.path:
    sys.path.append(target_path)
pos_path = f"{target_path}/q.npz"
mom_path = f"{target_path}/p.npz"
dpos_path = f"{target_path}/dq.npz"
dmom_path = f"{target_path}/dp.npz"

plt_pars = get_global_limits(pos_path)

# %%
q_path = f"{target_path}/q.npz"
p_path = f"{target_path}/p.npz"

# %%
start_idx = 1_600_000 # 2_000_000 * 0.8
dt = 0.0005 # 1 year = 2_000 steps, so 0.0005 corresponds to 1 step = 0.0005 year, and 1000 steps = 0.5 year,

# upto 50 Years
eval_steps = [1_000, 2_000, 4_000, 6_000, 8_000, 10_000, 20_000, 30_000, 40_000, 100_000]

if extend_time_window_upto_100Y:
   eval_steps += [200_000]


gt_q, gt_p = ground_truth_orbits(q_path, p_path, start_idx, eval_steps[-1])

if len(eval_steps) > 0:
    FIG_PREFIX = PREFIX
       
    eval_on_test_set(model, device, 
                 q_max, p_max, dq_max, dp_max, dt,
                 eval_steps, gt_q, gt_p, start_idx, 
                 FIG_PREFIX, weight_filename, EVAL_FIG_DIR,
                 plt_scale_pars=plt_pars, 
                 qp_cat=True, 
                 img_save=IMG_SAVE)
# Out:
# i: 0, interval=[0 : 1000]
# x0: (1, 60)
# /home/danieljh/py-venv/lib/python3.12/site-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# scipy_eval_[0 : 1000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# scipy_metric_[0 : 1000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# i: 1, interval=[0 : 2000]
# x0: (1, 60)
# scipy_eval_[0 : 2000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# scipy_metric_[0 : 2000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# i: 2, interval=[0 : 4000]
# x0: (1, 60)
# scipy_eval_[0 : 4000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# scipy_metric_[0 : 4000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# i: 3, interval=[0 : 6000]
# x0: (1, 60)
# scipy_eval_[0 : 6000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# scipy_metric_[0 : 6000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# i: 4, interval=[0 : 8000]
# x0: (1, 60)
# scipy_eval_[0 : 8000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# scipy_metric_[0 : 8000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# i: 5, interval=[0 : 10000]
# x0: (1, 60)
# scipy_eval_[0 : 10000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# scipy_metric_[0 : 10000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# i: 6, interval=[0 : 20000]
# x0: (1, 60)
# scipy_eval_[0 : 20000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# scipy_metric_[0 : 20000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# i: 7, interval=[0 : 30000]
# x0: (1, 60)
# scipy_eval_[0 : 30000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# scipy_metric_[0 : 30000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# i: 8, interval=[0 : 40000]
# x0: (1, 60)
# scipy_eval_[0 : 40000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# scipy_metric_[0 : 40000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# i: 9, interval=[0 : 100000]
# x0: (1, 60)
# scipy_eval_[0 : 100000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# scipy_metric_[0 : 100000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# i: 10, interval=[0 : 200000]
# x0: (1, 60)
# scipy_eval_[0 : 200000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
# scipy_metric_[0 : 200000]_mltsc-baseline-hnn(3)(240)_ep_500_of_500_bs_8192_lr_5e-03_pat_2.webp
